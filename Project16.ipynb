# %%
#NEUROMICS - PROJECT 16 Andrian Yang
#use <git clone> followed by the link of the github profile to obtain the file in your github 
#it will create a sort of folder in your github with a copy of the notebook

# the command <ls> always allows you to display the things inside that folder or pathway

# the command <mv> allows you to move files, the syntax mv - file that you want to move -
# - place where you want to move

# %%
#Cell range barcode graph <100 UMI is ambient, between 100-1000 need to be determine
#>1000 are cells

#UV is a virtual environment that you can create and install on VSCode

# %%
#There are two main repository for data to be published GEO and Array Express
#the download file download a .csv file and also another file with additional info

# %%
#the function rm -rf <environment> enable to remove all the 
# files in the environment selected
